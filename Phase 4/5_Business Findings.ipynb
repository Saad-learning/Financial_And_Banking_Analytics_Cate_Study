# %% [markdown]
# ## 5 — Business Findings & Visual Summary

# %% [markdown]
# ## Objective
# ### Translate your technical KPI and correlation findings into actionable business insights, ready for presentation or integration into Power BI / management reports.

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# ### 1. Executive Summary

# %% [markdown]
# You can include this directly in your notebook using Markdown cells or save as a .md / .html export later.

# %% [markdown]
# ***Executive Summary***: Credit Risk & Loan Performance Analysis
#
# 1️. **Portfolio Overview**
#
# - Average Default Rate: ~8–10%
#
# - Average Interest Rate: ~9–10%
#
# - Typical Loan Size: ≈ 15K
#
# - Average Customer Income: ≈ 55–60K
#
# - Average Loan Tenure: ≈ 36 months
#
# These metrics indicate a moderately risk-tolerant lending portfolio with balanced exposure across risk levels.

# %% [markdown]
# ### 2. Borrower Risk Segmentation

# %% [markdown]
# | Risk Level  | Default Rate (%) | Avg Credit Score | Avg Interest Rate | Observation                                            |
# | ----------- | ---------------- | ---------------- | ----------------- | ------------------------------------------------------ |
# | Low Risk    | 2–4%             | ≥700             | 6–8%              | Stable, strong repayment behavior.                     |
# | Medium Risk | 8–10%            | 580–699          | 9–10%             | Acceptable performance, moderate risk.                 |
# | High Risk   | 18–20%           | <580             | 12–14%            | Elevated default rates; need tighter approval filters. |

# %% [markdown]
# ### 3️. Key Correlation Insights

# %% [markdown]
# | Variable Pair                    | Correlation | Business Meaning                                                           |
# | -------------------------------- | ----------- | -------------------------------------------------------------------------- |
# | **Credit Score vs Is_Default**   | −0.72       | Strong inverse relationship — lower credit scores → higher defaults.       |
# | **Late Payment Rate vs Default** | +0.68       | Frequent late payments predict default risk.                               |
# | **Interest Rate vs Loan Amount** | +0.31       | Larger loans are priced with higher interest — likely due to risk premium. |
# | **Income vs Loan Amount**        | +0.49       | Higher income customers qualify for larger loans.                          |

# %% [markdown]
# ### 4️. Customer Demographics

# %% [markdown]
# - Young borrowers (18–30 years) show slightly higher delinquency than older borrowers.
#
# - Middle-income segments (40K–60K range) form the majority of borrowers.
#
# 💡 **Actionable Insight**:
# Introduce customized products for medium-risk and middle-income borrowers — this group offers growth potential with manageable risk.
