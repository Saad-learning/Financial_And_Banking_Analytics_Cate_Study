# %% [markdown]
# ### DataBase Connections

# %%
import pyodbc
import pandas as pd 
import numpy as np

DRIVER_NAME = 'ODBC Driver 17 for SQL Server'
SERVER_NAME = r'DESKTOP-L3GBMQ5\SQLEXPRESS'
DATABASE_NAME = 'Financial_CaseStudy'

connection_string = (
    f"DRIVER={{{DRIVER_NAME}}};"
    f"SERVER={SERVER_NAME};"
    f"DATABASE={DATABASE_NAME};"
    f"Trusted_Connection=yes;"
)

conn = pyodbc.connect(connection_string)
cursor = conn.cursor()
print("Connected successfully!")
# Out:
# Connected successfully!

# %% [markdown]
# ### Define SQL Query for KPI Calculation

# %%
kpi_query = """
-- KPI Calculation Query: Credit Risk & Loan Performance
SELECT
    ROUND(SUM(CASE WHEN Is_Default = 1 THEN 1 ELSE 0 END) * 100.0 / COUNT(*), 2) AS Default_Rate_Percent
    ,ROUND(AVG(Interest_Rate), 2) AS Avg_Interest_Rate
    ,ROUND(AVG(Loan_Amount), 2) AS Avg_Loan_Amount
    ,ROUND(AVG(Annual_Income), 2) AS Avg_Customer_Income
    ,ROUND(AVG(Loan_Term_Months), 2) AS Avg_Tenure_Months
FROM 
    dbo.dw_loan_analysis;
"""

# %% [markdown]
# ### Excute Query in SQL Server and Load into Pandas DataFrame

# %%
kpi_df = pd.read_sql(kpi_query, conn)
# Out:
# C:\Users\GIGABYTE\AppData\Local\Temp\ipykernel_5164\4160202268.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   kpi_df = pd.read_sql(kpi_query, conn)

# %% [markdown]
# ### KPI Results

# %%
print("Phase 4.1 - Credit Risk Portfolio KPIs:")
kpi_df
# Out:
# Phase 4.1 - Credit Risk Portfolio KPIs:
#    Default_Rate_Percent  Avg_Interest_Rate  Avg_Loan_Amount  \
# 0                   0.0              11.32          27595.8
#
#    Avg_Customer_Income  Avg_Tenure_Months
# 0             84936.07                 33
